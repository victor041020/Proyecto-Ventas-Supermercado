# %% [markdown]
# # CONTEXTO Y DESCRIPCION DEL PROBLEMA
#
# En el mercado minorista altamente competitivo, los supermercados enfrentan constantes desafíos para mejorar sus operaciones y satisfacer las necesidades de los clientes. En este análisis, se examinan los datos de ventas de un supermercado recopilados durante un período específico. Estos datos incluyen información sobre sucursales, clientes, productos, precios, ventas y satisfacción del cliente.

# %% [markdown]
# # ANALISIS EXPLORATORIO DE DATOS (EDA)
#
# El análisis exploratorio de datos (AED) es una fase fundamental en cualquier proyecto de análisis de datos. En este caso, el AED se enfocará en comprender la estructura y características del conjunto de datos de ventas del supermercado. A continuación, se describe cómo se llevará a cabo este proceso:

# %% [markdown]
# # IMPORTAR LIBRERIAS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # LIMPIEZA Y EXPLORACION DE DATOS

# %%
df = pd.read_csv("supermarket.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %%
df1 = df.drop(columns={"Invoice ID", "Tax 5%", "Total", "Time", "cogs", "gross margin percentage", "gross income"})
df1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity       Date      Payment  Rating
# 0         74.69         7   1/5/2019      Ewallet     9.1
# ...

# %%
df1["Total"] = df1["Unit price"] * df1["Quantity"]
df1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity       Date      Payment  Rating   Total
# 0         74.69         7   1/5/2019      Ewallet     9.1  522.83
# ...

# %%
columna_temporal = df1.pop('Total')

# Usamos insert para añadirla en la posición deseada
df1.insert(loc=7, column='Total', value=columna_temporal)
df1
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Total       Date      Payment  Rating
# 0         74.69         7  522.83   1/5/2019      Ewallet     9.1
# ...

# %%
df2 = df1.rename(columns={"Customer type": "Customer_type", "Product line": "Product_line", "Unit price": "Unit_price"})
df2
# Out:
#     Branch       City Customer_type  Gender            Product_line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit_price  Quantity   Total       Date      Payment  Rating
# 0         74.69         7  522.83   1/5/2019      Ewallet     9.1
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Branch         1000 non-null   object
#  1   City           1000 non-null   object
#  2   Customer_type  1000 non-null   object
#  3   Gender         1000 non-null   object
#  4   Product_line   1000 non-null   object
#  5   Unit_price     1000 non-null   float64
#  6   Quantity       1000 non-null   int64
#  7   Total          1000 non-null   float64
#  8   Date           1000 non-null   object
#  9   Payment        1000 non-null   object
#  10  Rating         1000 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 86.1+ KB

# %%
df2["Date"] = pd.to_datetime(df2["Date"])
df2
# Out:
#     Branch       City Customer_type  Gender            Product_line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit_price  Quantity   Total       Date      Payment  Rating
# 0         74.69         7  522.83 2019-01-05      Ewallet     9.1
# ...

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Branch         1000 non-null   object
#  1   City           1000 non-null   object
#  2   Customer_type  1000 non-null   object
#  3   Gender         1000 non-null   object
#  4   Product_line   1000 non-null   object
#  5   Unit_price     1000 non-null   float64
#  6   Quantity       1000 non-null   int64
#  7   Total          1000 non-null   float64
#  8   Date           1000 non-null   datetime64[ns]
#  9   Payment        1000 non-null   object
#  10  Rating         1000 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(6)
# memory usage: 86.1+ KB

# %% [markdown]
# # ANALISIS ESTADISTICO
#
# VARIABLES CUANTITATIVAS:
#
# Este análisis proporcionará una visión general de la distribución y características principales de estas variables.
#
# - Unit_price:
#
# Media: $55.67
# Desviación estándar: $26.49
# Valor mínimo: $10.08
# Valor máximo: $99.96
#
# - Quantity:
#
# Media: 5.51 unidades
# Desviación estándar: 2.92 unidades
# Valor mínimo: 1 unidad
# Valor máximo: 10 unidades
#
# - Total:
#
# Media: $307.59
# Desviación estándar: $234.18
# Valor mínimo: $10.17
# Valor máximo: $993.00
#
# - Rating:
#
# Media: 6.97
# Desviación estándar: 1.72
# Valor mínimo: 4.00
# Valor máximo: 10.00
#
#
# Estos resúmenes estadísticos proporcionan una comprensión concisa de la distribución y variabilidad de las variables clave en el conjunto de datos de ventas del supermercado.
#
#
#
#
#
#
# e 5.50, mientras que el 75% están por debajo de 8.50.

# %%
df2.describe(include="number")
# Out:
#         Unit_price     Quantity       Total      Rating
# count  1000.000000  1000.000000  1000.00000  1000.00000
# mean     55.672130     5.510000   307.58738     6.97270
# std      26.494628     2.923431   234.17651     1.71858
# min      10.080000     1.000000    10.17000     4.00000
# 25%      32.875000     3.000000   118.49750     5.50000
# 50%      55.230000     5.000000   241.76000     7.00000
# 75%      77.935000     8.000000   448.90500     8.50000
# max      99.960000    10.000000   993.00000    10.00000

# %%
df2["Unit_price"].plot.box()
# Out:
# <Axes: >

# %%
df2["Quantity"].plot.box()
# Out:
# <Axes: >

# %%
df2["Total"].plot.box()
# Out:
# <Axes: >

# %%
df2["Rating"].plot.box()
# Out:
# <Axes: >

# %% [markdown]
# # PREGUNTAS OBJETIVO

# %% [markdown]
# 1. Análisis General de Ventas
# Pregunta: ¿Cuál es el ingreso total generado por las ventas para cada sucursal?
#
# Respuesta:

# %%
total_ventas = df2.groupby("Branch")["Total"].sum()
total_ventas = total_ventas.sort_values(ascending=False)
total_ventas
# Out:
# Branch
# C    105303.53
# A    101143.21
# B    101140.64
# Name: Total, dtype: float64

# %% [markdown]
# 2. Comportamiento de Compra por Ciudad y Sucursal
# Pregunta: ¿Cómo varían las ventas (en términos de ingresos totales) entre las diferentes ciudades donde se encuentran las sucursales?
#
# Respuesta:

# %%
total_vent_ciudad = df2.groupby("City")["Total"].sum()
total_vent_ciudad = total_vent_ciudad.sort_values(ascending=False)
total_vent_ciudad
# Out:
# City
# Naypyitaw    105303.53
# Yangon       101143.21
# Mandalay     101140.64
# Name: Total, dtype: float64

# %% [markdown]
# 3. Preferencias de Producto
# Pregunta: ¿Cuáles son las líneas de productos más vendidas?
#
# Respuesta:

# %%
linea_pro_mas_ven = df2.groupby("Product_line")["Quantity"].sum()
linea_pro_mas_ven = linea_pro_mas_ven.sort_values(ascending=False)
linea_pro_mas_ven
# Out:
# Product_line
# Electronic accessories    971
# Food and beverages        952
# Sports and travel         920
# Home and lifestyle        911
# Fashion accessories       902
# Health and beauty         854
# Name: Quantity, dtype: int64

# %% [markdown]
# 4. Preferencias de Producto
# Pregunta: ¿Cuáles son las líneas de productos que generan más ingresos?
#
# Respuesta:

# %%
linea_pro_mas_ingreso = df2.groupby("Product_line")["Total"].sum()
linea_pro_mas_ingreso = linea_pro_mas_ingreso.sort_values(ascending=False)
linea_pro_mas_ingreso
# Out:
# Product_line
# Food and beverages        53471.28
# Sports and travel         52497.93
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Home and lifestyle        51297.06
# Health and beauty         46851.18
# Name: Total, dtype: float64

# %% [markdown]
# 5. Dinámica de Precios y Cantidad
# Pregunta: ¿Existe alguna correlación entre el precio unitario de los productos y la cantidad vendida?
#
# Respuesta:

# %%
corr_preciouni_cant = df2["Unit_price"].corr(df2["Quantity"])
corr_preciouni_cant
# Out:
# 0.010777564342497267

# %% [markdown]
# 6. Comportamiento de los Clientes
# Pregunta: ¿Difieren los patrones de compra entre miembros y no miembros?
#
# Respuesta:

# %%
compra_por_tipocli = df2.groupby("Customer_type")["Total"].sum()
compra_por_tipocli = compra_por_tipocli.sort_values(ascending=False)
compra_por_tipocli
# Out:
# Customer_type
# Member    156403.28
# Normal    151184.10
# Name: Total, dtype: float64

# %% [markdown]
# 7. Comportamiento de los Clientes
# Pregunta: ¿Difieren los patrones de compra entre géneros?
#
# Respuesta:

# %%
compras_por_genero = df2.groupby("Gender")["Total"].sum()
compras_por_genero = compras_por_genero.sort_values(ascending=False)
compras_por_genero
# Out:
# Gender
# Female    159888.50
# Male      147698.88
# Name: Total, dtype: float64

# %% [markdown]
# 8. Análisis Temporal de las Ventas
# Pregunta: ¿Cómo varían las ventas a lo largo de los tres meses? ¿Hay algún patrón o tendencia visible?
#
# Respuesta:

# %%
df2["Month"] = df2["Date"].dt.month
df2
# Out:
#     Branch       City Customer_type  Gender            Product_line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit_price  Quantity   Total       Date      Payment  Rating  Month
# 0         74.69         7  522.83 2019-01-05      Ewallet     9.1      1
# ...

# %%
df2["Month"] = df2["Month"].replace({1: "January", 2: "February", 3: "March"})
df2
# Out:
#     Branch       City Customer_type  Gender            Product_line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit_price  Quantity   Total       Date      Payment  Rating     Month
# ...

# %%
# Remover la columna 'Month' del DataFrame y almacenarla en una variable temporal
month_column = df2.pop('Month')

# Insertar la columna 'Month' en la nueva posición deseada
df2.insert(9, 'Month', month_column)  # Inserta en la posición índice 2

# Imprimir el DataFrame después de mover la columna
df2
# Out:
#     Branch       City Customer_type  Gender            Product_line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit_price  Quantity   Total       Date     Month      Payment  Rating
# ...

# %%
ventas_por_meses = df2.groupby("Month")["Total"].sum()
ventas_por_meses = ventas_por_meses.sort_values(ascending=False)
ventas_por_meses
# Out:
# Month
# January     110754.16
# March       104243.34
# February     92589.88
# Name: Total, dtype: float64

# %% [markdown]
# 9. Métodos de Pago
# Pregunta: ¿Qué método de pago es el más utilizado por los clientes en cada sucursal?
#
# Respuesta:

# %%
df2["Payment"].value_counts()
# Out:
# Payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %% [markdown]
# 10. Satisfacción del Cliente
# Pregunta: ¿Cómo se relaciona la calificación de satisfacción del cliente con el volumen de ventas?
#
# Respuesta:

# %%
corr_volclien_vent = df2["Rating"].corr(df2["Total"])
corr_volclien_vent
# Out:
# -0.036441704997018334

# %% [markdown]
# 11. Satisfacción del Cliente
# Pregunta: ¿Los productos con mayores ventas tienen mejores calificaciones?
#
# Respuesta:

# %%
prod_mas_rait = df2.groupby("Product_line")["Rating"].mean()
prod_mas_rait = prod_mas_rait.sort_values(ascending=False)
prod_mas_rait
# Out:
# Product_line
# Food and beverages        7.113218
# Fashion accessories       7.029213
# Health and beauty         7.003289
# Electronic accessories    6.924706
# Sports and travel         6.916265
# Home and lifestyle        6.837500
# Name: Rating, dtype: float64

# %%
prod_mas_vent = df2.groupby("Product_line")["Total"].sum()
prod_mas_vent = prod_mas_vent.sort_values(ascending=False)
prod_mas_vent
# Out:
# Product_line
# Food and beverages        53471.28
# Sports and travel         52497.93
# Electronic accessories    51750.03
# Fashion accessories       51719.90
# Home and lifestyle        51297.06
# Health and beauty         46851.18
# Name: Total, dtype: float64

# %%
df2["Product_line"].value_counts()
# Out:
# Product_line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %% [markdown]
# # CONCLUSIONES
#
# 1.	Desempeño de las Sucursales:
# •	Las ventas totales muestran una distribución relativamente equitativa entre las sucursales, con ingresos generados cercanos entre sí. Sin embargo, la Sucursal C destaca ligeramente con el ingreso total más alto.
#
# 2.	Varianza en Ventas por Ciudad:
# •	La ciudad de Naypyitaw lidera en términos de ingresos totales generados por ventas, seguida de Yangon y Mandalay.
#
# 3.	Preferencias de Producto:
# •	Las líneas de productos más vendidas incluyen accesorios electrónicos, alimentos y bebidas, y artículos deportivos y de viaje.
# •	En términos de ingresos, los productos alimenticios y las categorías relacionadas con el estilo de vida generan los mayores ingresos.
#
# 4.	Correlación Precio-Cantidad:
# •	Existe una correlación muy débil entre el precio unitario de los productos y la cantidad vendida, lo que sugiere que el precio no es un factor determinante en la cantidad de productos vendidos.
#
# 5.	Patrones de Compra por Segmento de Cliente:
# •	Los miembros del supermercado parecen gastar ligeramente más que los no miembros, lo que indica una posible preferencia por servicios adicionales o promociones exclusivas.
# •	No se observan diferencias significativas en los patrones de compra entre géneros.
#
# 6.	Tendencias Temporales:
# •	Las ventas muestran una fluctuación mensual, con un pico en enero seguido de una disminución en febrero y un ligero aumento en marzo. Se necesita un análisis adicional para identificar las razones detrás de estas variaciones.
#
# 7.	Preferencias de Pago:
# •	El método de pago más utilizado varía entre Ewallet y efectivo, siendo estos los métodos de elección en las transacciones del supermercado.
#
# 8.	Satisfacción del Cliente:
# •	Existe una correlación negativa muy débil entre la calificación de satisfacción del cliente y el volumen de ventas, lo que sugiere que los clientes no siempre califican la satisfacción en función del volumen de sus compras.
# •	No hay una relación clara entre las calificaciones de los productos y sus ventas, lo que indica que la popularidad de un producto no siempre coincide con su calificación.

# %% [markdown]
# # EXPORTACION DE LA BASE DE DATOS

# %%
df2.to_excel('supermarket.xlsx', index=False)
